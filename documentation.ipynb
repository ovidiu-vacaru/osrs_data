# %%
import requests

# %%
 r = requests.get(
            f"http://services.runescape.com/m=itemdb_rs/api/catalogue/detail.json?item={id}"
        )
print(r.content)
print(r)
# Out:
# m-link\'>\r\n\t\t\t\t\t\t\t\t\t\t\t\t<img class=\'table-item-image\' src=\'https://secure.runescape.com/m=itemdb_oldschool/1614259272910_obj_sprite.gif?id=19493\' alt="Zenyte" title="Zenyte"/><span>Zenyte</span>\r\n\t\t\t\t\t\t\t\t\t\t\t</a>\r\n\t\t\t\t\t\t\t\t\t\t</td>\r\n\t\t\t\t\t\t\t\t\t\t<td class=\'memberItem\'><img src=\'https://www.runescape.com/img/rsp777/grand_exchange/tick.png\' title="Members Only" alt="Yes" /></td>\r\n\t\t\t\t\t\t\t\t\t\t\t<td><a href="https://secure.runescape.com/m=itemdb_oldschool/Zenyte/viewitem?obj=19493">0</a></td>\r\n\t\t\t\t\t\t\t\t\t\t\t<td><a href="https://secure.runescape.com/m=itemdb_oldschool/Zenyte/viewitem?obj=19493">14.4m</a></td>\r\n\t\t\t\t\t\t\t\t\t\t\t<td><a href="https://secure.runescape.com/m=itemdb_oldschool/Zenyte/viewitem?obj=19493">14.8m</a></td>\r\n\t\t\t\t\t\t\t\t\t\t\t\t<td><a href="https://secure.runescape.com/m=itemdb_oldschool/Zenyte/viewitem?obj=19493">15.2m</a></td>\r\n\t\t\t\t\t\t\t\t\t</tr>\r\n\t\t\t\t\t\t\t\t\t<tr>\r\n
# ...
